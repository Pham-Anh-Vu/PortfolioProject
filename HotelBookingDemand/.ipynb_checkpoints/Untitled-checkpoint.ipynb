# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
df
# Out:
#         index         hotel  is_canceled  lead_time  adults  children  babies  \
# 0           0  Resort Hotel            0        342       2         0       0
# 1           1  Resort Hotel            0        737       2         0       0
# 2           2  Resort Hotel            0          7       1         0       0
# 3           3  Resort Hotel            0         13       1         0       0
# 4           4  Resort Hotel            0         14       2         0       0
# ...       ...           ...          ...        ...     ...       ...     ...
# 87391  119385    City Hotel            0         23       2         0       0
# 87392  119386    City Hotel            0        102       3         0       0
# 87393  119387    City Hotel            0         34       2         0       0
# 87394  119388    City Hotel            0        109       2         0       0
# 87395  119389    City Hotel            0        205       2         0       0
#
# ...

# %%
df = df.drop_duplicates()

# %%
for i in df.columns:
  if df[i].isna().sum() != 0:
    print('null values in', i, 'column :', df[i].isna().sum() )

# %%
df = df.dropna(subset = ['children'])
df['country'].fillna(df['country'].mode()[0], inplace = True)
df['agent'].fillna(0, inplace = True)

# %%
df
# Out:
#         index         hotel  is_canceled  lead_time  arrival_date_year  \
# 0           0  Resort Hotel            0        342               2015
# 1           1  Resort Hotel            0        737               2015
# 2           2  Resort Hotel            0          7               2015
# 3           3  Resort Hotel            0         13               2015
# 4           4  Resort Hotel            0         14               2015
# ...       ...           ...          ...        ...                ...
# 87391  119385    City Hotel            0         23               2017
# 87392  119386    City Hotel            0        102               2017
# 87393  119387    City Hotel            0         34               2017
# 87394  119388    City Hotel            0        109               2017
# 87395  119389    City Hotel            0        205               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df['distribution_channel'].replace("TA/TO", "Undefined", inplace = True)

# %%
df['meal'].replace(['Undefined', 'BB', 'FB', 'HB', 'SC'], 
                   [ 'No Meal', 'Breakfast', 'Full Board', 'Hald Board', 'No Meal'],
                   inplace = True)

# %%
df['children'] = df['children'].astype(int)
df['agent'] = df['agent'].astype(int)

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87373 entries, 0 to 119389
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87373 non-null  object
#  1   is_canceled                     87373 non-null  int64
#  2   lead_time                       87373 non-null  int64
#  3   adults                          87373 non-null  int64
#  4   children                        87373 non-null  int32
#  5   babies                          87373 non-null  int64
#  6   meal                            87373 non-null  object
#  7   country                         87373 non-null  object
#  8   market_segment                  87373 non-null  object
#  9   distribution_channel            87373 non-null  object
#  10  is_repeated_guest               87373 non-null  int64
#  11  previous_cancellations          87373 non-null  int64
# ...

# %%
df['distribution_channel']
# Out:
# 0            Direct
# 1            Direct
# 2            Direct
# 3         Corporate
# 4         Undefined
#             ...
# 119385    Undefined
# 119386    Undefined
# 119387    Undefined
# 119388    Undefined
# 119389    Undefined
# Name: distribution_channel, Length: 87373, dtype: object

# %%
df['meal']
# Out:
# 0          Breakfast
# 1          Breakfast
# 2          Breakfast
# 3          Breakfast
# 4          Breakfast
#              ...
# 119385     Breakfast
# 119386     Breakfast
# 119387     Breakfast
# 119388     Breakfast
# 119389    Hald Board
# Name: meal, Length: 87373, dtype: object

# %%
df['total_night'] = df['stays_in_week_nights'] + df['stays_in_weekend_nights']

# %%
df['arrival_date_month'] = pd.to_datetime(df['arrival_date_month'] , format='%B').dt.month

# %%
df['arrival_date'] = pd.to_datetime(dict(year=df.arrival_date_year, month=df.arrival_date_month, day=df.arrival_date_day_of_month))

# %%
df['arrival_date']
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-01
# 3        2015-07-01
# 4        2015-07-01
#             ...
# 119385   2017-08-30
# 119386   2017-08-31
# 119387   2017-08-31
# 119388   2017-08-31
# 119389   2017-08-29
# Name: arrival_date, Length: 87373, dtype: datetime64[ns]

# %%
columns_to_drop = ['stays_in_weekend_nights','stays_in_week_nights', 
'booking_changes','deposit_type','adr','arrival_date_year',
'arrival_date_month','arrival_date_day_of_month','arrival_date_week_number']
#drop
df.drop(columns = columns_to_drop, inplace = True)

# %%
df.describe()
# Out:
#         is_canceled     lead_time        adults      children        babies  \
# count  87373.000000  87373.000000  87373.000000  87373.000000  87373.000000
# mean       0.274913     79.909377      1.875888      0.138670      0.010827
# std        0.446473     86.055917      0.626486      0.455926      0.113611
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000     11.000000      2.000000      0.000000      0.000000
# 50%        0.000000     49.000000      2.000000      0.000000      0.000000
# 75%        1.000000    125.000000      2.000000      0.000000      0.000000
# max        1.000000    737.000000     55.000000     10.000000     10.000000
#
#        is_repeated_guest  previous_cancellations  \
# count       87373.000000            87373.000000
# mean            0.039085                0.030421
# std             0.193799                0.369194
# min             0.000000                0.000000
# ...

# %%
plt.rcParams['figure.figsize'] =(12, 6)
sns.heatmap(df.corr(), annot=True, cmap='Reds')
plt.suptitle('Correlation Between Variables', fontweight='heavy', 
             x=0.03, y=0.98, ha = "left", fontsize='18', 
             fontfamily='sans-serif', color= "black")
# Out:
# C:\Users\NTS\AppData\Local\Temp\ipykernel_1316\125775197.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='Reds')
# Text(0.03, 0.98, 'Correlation Between Variables')

# %%
df.to_csv('result.csv', index=False)

# %% [markdown]
# ### Booking
# 1. What is the big picture of room booking over year and month?
# 2. What are the most effective booking channels?
# 3. Are the guesses interested in booking meals along with their room reservation?
#
# ### Hotel
# 4. What are the most popular hotels and how many booking they have over the year?
# 5. Compare those hotel on type of customers?
# 6. Compare those hotels on customers's group?
#
# ### Customer
# 7. What is trend of customer requests during their stay in different room types?
# 8. What market segment has highest repeated guest rate and highest stay duration?
# 9. Is the number of customer in baby group affect their parents's decision in booking meals and stay duration
# 10. What types of room are most popular for children and babies?

# %% [markdown]
# **1.What is the big picture of room booking over year and month?**

# %% [markdown]
# Room booking in three years period

# %% [markdown]
# Most rooms are check out while there are still big proportion of rooms are being canceled. The number of of rooms that are booked but the customers were not show up was inconsiderable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Room booking break down by months

# %% [markdown]
# There is a big hit in 2016, there is anincrease the number of room booked. The trend indicates that busy reason is start from April until July.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **2. What are the most effective booking channels?**

# %% [markdown]
# There are still a large number of booking channels are undefined. Besides that, it seems like direct channel still play a huge role in hotel reservation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Booking channel over time**

# %% [markdown]
# While there are more and more undefined channels over time, the trend of direct and corporate channels remain quite stable over the year. GDS booking channel is not very effective overall.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **3. Are the guesses interested in booking meals along with their stay duration?**

# %% [markdown]
# Yes, the more nights they stay, the more meals are booked. July and August 2016 seem to have a huge demand for meal and reserved rooms. Although, demand fell from September 2016 to December 2016 but it increased again from beginning of 2017

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **4. What ra the most popular hotels and how many booking they have over the year?**

# %% [markdown]
# We have records of two hotel: City Hotel and Resort Hotel
# They started with the approximately same sales in 2015, but City Hotel got much more customers in 2016 reached nearly 26800 reservation, while Resort Hotel stayed at 15600 reservations. The difference ratio remains in 2017.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **5. Compare those hotels on customers'group?**

# %% [markdown]
# Adult is the highest group with more 10 times higher than children group and more 30 times higher than baby group. The difference ratio remains the same for Resort Hotel

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **6. Compares hotels on Customer Type**

# %% [markdown]
# Transient is the main customer type, followed by Transient-Party and contract customer type. However, Resort Hotel data show a higher portion Contract customer type approximate 14300 while the number for City Hotel only at 4600.
#
# Group customer type is inconsiderable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **7. What is trend of customer requests during their stay in different room type?**

# %% [markdown]
# Well, the more special request the customer made, the more parking space requests they have. These data for two request are quite correlated. We can see the customers in room A and D has the highest number for both requests.

# %% [markdown]
# We can assume that they are more popular rooms leading to the higher demand for requests

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **8. What market segment has highest repeated guest rate and highest stay duration?**

# %% [markdown]
# This chart give us both data about the number of repeated guest and total stay grouped by market segment.
#
# Corporate segment has the highest number of repeated guest at 1445 guests, but their total of nights is quite low. Meanwhile, 579 online TA guests booked the hotel again, there total of stay duration is the highest at 186203 nights.
#
# Aviation and Groups segment data saw both little quantity in both repeated guest and stay durations.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **9. Is the number of customer in baby group affect their parents's decision in booking meals and stay duration?**

# %% [markdown]
# Yes, family with babies tend to book more breakfast, but less in full board and no meal. These customers also stay more nights compared to the rest.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **10. What types of room are most popular for children and babies?**

# %% [markdown]
# Three most popular room for children: A, F, G
# Three most popular room for babies: A, D, E
# So room A is best suit for customers with children and babies.
#
# Meanwhile, room B, H are quite unpopular among customers' choice

# %% [markdown]
# ![image.png](attachment:image.png)
